# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.DataFrame(data=[None],
            index=[None],
            columns=[None]) #Empty pandas DataFrame
# Out:
#       None
# None  None

# %%
marvel_data = [
    ['Spider-Man','male',1962],
    ['Captain America','male',1941],
    ['Wolverine','male',1974],
    ['Iron Man','male',1963],
    ['Thor','male',1963],
    ['Thing','male',1961],
    ['Mister Fantastic','male',1961],
    ['Hulk','male',1962],
    ['Beast','male',1963],
    ['Invisible Woman','female',1961],
    ['Storm','female',1975],
    ['Namor','male',1939],
    ['Hawkeye','male',1964],
    ['Daredevil','male',1964],
    ['Doctor Strange','male',1963],
    ['Hank Pym','male',1962],
    ['Scarlet Witch','female',1964],
    ['Wasp','female',1964],
    ['Black Widow','female',1964],
    ['Vision','male',1968]
]

# %%
marvel_df = pd.DataFrame(data=marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1964
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
col_names = ['name','sex','first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1964
# 18       Black Widow  female              1964
# ...

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
marvel_df = marvel_df.drop(['name'], axis=1) #marvel_df.drop(columns=['name'] or axis=columns)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1964
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df = marvel_df.drop(['Namor','Hank Pym'], axis=0)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1964
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df.head()
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
#marvel_df.iloc[:5,]
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
marvel_df.tail()
#marvel_df.iloc[-5:,]
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1964
# Black Widow     female              1964
# Vision            male              1968

# %%
marvel_df.head().sex.to_frame()
#marvel_df.iloc[:5,]['sex'].to_frame()
#marvel_df.iloc[:5,].sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame() #middle items (middle means everything but the edges)
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1964
# Black Widow                   1964

# %%
marvel_df.iloc[[0,-1],]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
marvel_df.loc['Vision','first_appearance'] = 1964 #first loc the index then the modifying feature
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1964
# Black Widow       female              1964
# Vision              male              1964

# %%
marvel_df['years_since'] = 2022 - marvel_df['first_appearance']
marvel_df
# Out:
#                      sex  first_appearance  years_since
# name
# Spider-Man          male              1962           60
# Captain America     male              1941           81
# Wolverine           male              1974           48
# Iron Man            male              1963           59
# Thor                male              1963           59
# Thing               male              1961           61
# Mister Fantastic    male              1961           61
# Hulk                male              1962           60
# Beast               male              1963           59
# Invisible Woman   female              1961           61
# Storm             female              1975           47
# Hawkeye             male              1964           58
# Daredevil           male              1964           58
# Doctor Strange      male              1963           59
# Scarlet Witch     female              1964           58
# Wasp              female              1964           58
# ...

# %%
mask = marvel_df['sex'] == 'female'
mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'male'
marvel_df[mask]
# Out:
#                    sex  first_appearance  years_since
# name
# Spider-Man        male              1962           60
# Captain America   male              1941           81
# Wolverine         male              1974           48
# Iron Man          male              1963           59
# Thor              male              1963           59
# Thing             male              1961           61
# Mister Fantastic  male              1961           61
# Hulk              male              1962           60
# Beast             male              1963           59
# Hawkeye           male              1964           58
# Daredevil         male              1964           58
# Doctor Strange    male              1963           59
# Vision            male              1964           58

# %%
mask = marvel_df['first_appearance'] > 1970
marvel_df[mask]
# Out:
#          name     sex  first_appearance  years_since
# 2   Wolverine    male              1974           48
# 10      Storm  female              1975           47

# %%
mask = (marvel_df['first_appearance'] > 1970) & (marvel_df['sex'] == 'female')
marvel_df[mask]
# Out:
#      name     sex  first_appearance  years_since
# 10  Storm  female              1975           47

# %%
marvel_df.describe()
# Out:
#        first_appearance  years_since
# count         18.000000    18.000000
# mean        1962.944444    59.055556
# std            6.725476     6.725476
# min         1941.000000    47.000000
# 25%         1962.000000    58.000000
# 50%         1963.000000    59.000000
# 75%         1964.000000    60.000000
# max         1975.000000    81.000000

# %%
marvel_df['first_appearance'].mean()
# Out:
# 1962.9444444444443

# %%
marvel_df['first_appearance'].min()
# Out:
# 1941

# %%
mask2 = marvel_df['first_appearance'] == marvel_df['first_appearance'].min()
marvel_df[mask2]
# Out:
#               name   sex  first_appearance  years_since
# 1  Captain America  male              1941           81

# %%
marvel_df = marvel_df.reset_index()
marvel_df
# Out:
#     index              name     sex  first_appearance  years_since
# 0       0        Spider-Man    male              1962           60
# 1       1   Captain America    male              1941           81
# 2       2         Wolverine    male              1974           48
# 3       3          Iron Man    male              1963           59
# 4       4              Thor    male              1963           59
# 5       5             Thing    male              1961           61
# 6       6  Mister Fantastic    male              1961           61
# 7       7              Hulk    male              1962           60
# 8       8             Beast    male              1963           59
# 9       9   Invisible Woman  female              1961           61
# 10     10             Storm  female              1975           47
# 11     11           Hawkeye    male              1964           58
# 12     12         Daredevil    male              1964           58
# ...

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()
# Out:
# <AxesSubplot:>

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 12.,  0.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <BarContainer object of 10 artists>)
